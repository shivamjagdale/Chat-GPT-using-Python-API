# %%
# !pip install openai

# %%
import openai

# %%
from openai import OpenAI

# %%
# Here we pass api key in open ai

client = OpenAI(api_key="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")

# %% [markdown]
# # **For General Chat**

# %%
response = client.chat.completions.create(model="gpt-3.5-turbo",

                                          messages=[
                                                    {"role":"system", "content":"You are an helpful assistant"},

                                                    {"role":"user", "content":"Who won the baseball in 2020?"},
                                                    {"role":"assistant", "content":"The dodgers"},

                                                    {"role":"user", "content":"Where was the game played?"}
                                                    ])

# %%
print(response.choices[0].message.content)

# %% [markdown]
# # **For Images**

# %%
response_images = client.chat.completions.create(model="gpt-3.5-turbo",

                                                 messages=[
                                                           {"role":"system", "content":"You are my helpful assistant"},

                                                           {"role":"user", "content":[{"type":"text", "text":"what do you see in this image?"},
                                                                                      {"type":"img_url", "img_url":"https://hips.hearstapps.com/hmg-prod/images/dog-puppy-on-garden-royalty-free-image-1586966191.jpg?crop=0.752xw:1.00xh;0.175xw,0&resize=1200:*"}
                                                                                      ]}

                                                           ])

# %%
print(response.choices[0].message.content)
